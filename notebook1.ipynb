# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # read data from csv file into a dataframe

# %%
data_1 = pd.read_csv("dataset_1.csv")
data_1
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0          1  01-01-2011       1   0     1   0    False        6           1
# 1          2  01-01-2011       1   0     1   1    False        6           1
# 2          3  01-01-2011       1   0     1   2    False        6           1
# 3          4  01-01-2011       1   0     1   3    False        6           1
# 4          5  01-01-2011       1   0     1   4    False        6           1
# ..       ...         ...     ...  ..   ...  ..      ...      ...         ...
# 605      606  28-01-2011       1   0     1  11    False        5           3
# 606      607  28-01-2011       1   0     1  12    False        5           3
# 607      608  28-01-2011       1   0     1  13    False        5           3
# 608      609  28-01-2011       1   0     1  14    False        5           3
# 609      610  28-01-2011       1   0     1  15    False        5           2
#
#      temp
# 0    0.24
# 1    0.22
# ...

# %%
#understanding the data for data cleaning by having data summary
# using shape,display info and describe for the summary

# %%
data_1.shape
# Out:
# (610, 10)

# %%
print("Displaying the info of dataset")
print(data_1.info())
# Out:
# Displaying the info of dataset
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 610 entries, 0 to 609
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     610 non-null    int64
#  1   dteday      610 non-null    object
#  2   season      610 non-null    int64
#  3   yr          610 non-null    int64
#  4   mnth        610 non-null    int64
#  5   hr          610 non-null    int64
#  6   holiday     610 non-null    bool
#  7   weekday     610 non-null    int64
#  8   weathersit  610 non-null    int64
#  9   temp        610 non-null    float64
# dtypes: bool(1), float64(1), int64(7), object(1)
# memory usage: 43.6+ KB
# None

# %%
data_1.describe()
# Out:
#           instant  season     yr   mnth          hr     weekday  weathersit  \
# count  610.000000   610.0  610.0  610.0  610.000000  610.000000  610.000000
# mean   305.500000     1.0    0.0    1.0   11.795082    2.977049    1.477049
# std    176.236111     0.0    0.0    0.0    6.852107    2.054943    0.643496
# min      1.000000     1.0    0.0    1.0    0.000000    0.000000    1.000000
# 25%    153.250000     1.0    0.0    1.0    6.000000    1.000000    1.000000
# 50%    305.500000     1.0    0.0    1.0   12.000000    3.000000    1.000000
# 75%    457.750000     1.0    0.0    1.0   18.000000    5.000000    2.000000
# max    610.000000     1.0    0.0    1.0   23.000000    6.000000    4.000000
#
#              temp
# count  610.000000
# mean     0.196885
# std      0.081304
# min      0.020000
# 25%      0.160000
# 50%      0.200000
# 75%      0.235000
# max      0.460000

# %%
data_1.isnull().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# weathersit    0
# temp          0
# dtype: int64

# %%
#dropping nul values if preesent

data_1.dropna(inplace =True)
data_1
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0          1  01-01-2011       1   0     1   0    False        6           1
# 1          2  01-01-2011       1   0     1   1    False        6           1
# 2          3  01-01-2011       1   0     1   2    False        6           1
# 3          4  01-01-2011       1   0     1   3    False        6           1
# 4          5  01-01-2011       1   0     1   4    False        6           1
# ..       ...         ...     ...  ..   ...  ..      ...      ...         ...
# 605      606  28-01-2011       1   0     1  11    False        5           3
# 606      607  28-01-2011       1   0     1  12    False        5           3
# 607      608  28-01-2011       1   0     1  13    False        5           3
# 608      609  28-01-2011       1   0     1  14    False        5           3
# 609      610  28-01-2011       1   0     1  15    False        5           2
#
#      temp
# 0    0.24
# 1    0.22
# ...

# %%
#here i am checking,whether there is any duplicate rows or columns in the dataset
#As there are no such duplicates,we will not perform the code to remove duplicates

duplicate_rows = data_1.duplicated()
print("Number of duplicate rows:", duplicate_rows.sum())
duplicate_columns = data_1.duplicated()
print("Number of duplicate columns:", duplicate_columns.sum())
# Out:
# Number of duplicate rows: 0
# Number of duplicate columns: 0

# %%
#checking unique values for each column
# Count of unique values per column

unique_counts = data_1.nunique()

print(unique_counts)
# Out:
# instant       610
# dteday         28
# season          1
# yr              1
# mnth            1
# hr             24
# holiday         2
# weekday         7
# weathersit      4
# temp           23
# dtype: int64

# %%
#changing the dtype of dteday as it can not be object. so converting it into datetime.
#other columns dtypes are correct so we will not change them.

data_1['dteday'] = pd.to_datetime(data_1['dteday'], format='%d-%m-%Y')
print(data_1)
# Out:
#      instant     dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0          1 2011-01-01       1   0     1   0    False        6           1
# 1          2 2011-01-01       1   0     1   1    False        6           1
# 2          3 2011-01-01       1   0     1   2    False        6           1
# 3          4 2011-01-01       1   0     1   3    False        6           1
# 4          5 2011-01-01       1   0     1   4    False        6           1
# ..       ...        ...     ...  ..   ...  ..      ...      ...         ...
# 605      606 2011-01-28       1   0     1  11    False        5           3
# 606      607 2011-01-28       1   0     1  12    False        5           3
# 607      608 2011-01-28       1   0     1  13    False        5           3
# 608      609 2011-01-28       1   0     1  14    False        5           3
# 609      610 2011-01-28       1   0     1  15    False        5           2
#
#      temp
# 0    0.24
# 1    0.22
# 2    0.22
# ...

# %%
data_1['holiday'] = data_1['holiday'].map({'FALSE': False, 'TRUE': True})
data_1['holiday'] = data_1['holiday'].astype(bool)

# %%
print(data_1['holiday'].dtype)
# Out:
# bool

# %%
#Dropping the 'yr','mnth'column, because it is of no use as dteday column is giving the information .

finaldata_1 = data_1.drop(columns=['yr','mnth'])
print(finaldata_1)
# Out:
#      instant     dteday  season  hr  holiday  weekday  weathersit  temp
# 0          1 2011-01-01       1   0     True        6           1  0.24
# 1          2 2011-01-01       1   1     True        6           1  0.22
# 2          3 2011-01-01       1   2     True        6           1  0.22
# 3          4 2011-01-01       1   3     True        6           1  0.24
# 4          5 2011-01-01       1   4     True        6           1  0.24
# ..       ...        ...     ...  ..      ...      ...         ...   ...
# 605      606 2011-01-28       1  11     True        5           3  0.18
# 606      607 2011-01-28       1  12     True        5           3  0.18
# 607      608 2011-01-28       1  13     True        5           3  0.18
# 608      609 2011-01-28       1  14     True        5           3  0.22
# 609      610 2011-01-28       1  15     True        5           2  0.20
#
# [610 rows x 8 columns]

# %% [markdown]
# # making some EDAs for better understanding for dataset.
#
# # What 1st chart shows:
# Each bar represents a weekday (0=Sunday, 1=Monday, ..., 6=Saturday).
#
# The height of the bar shows how many times a holiday occurs on that weekday (in your dataset, each row is an hour, so this is the number of holiday hours per weekday).
#
# # The second graph gives a clear, visual comparison between holidays and non-holidays for each weekday
#
# # the third graph shows the average temperature for each season.Also, have found the stats in beginning of code under summary markdown.

# %%
# Count number of holidays per weekday
holiday_counts = finaldata_1[finaldata_1['holiday']].groupby('weekday').size()

# Plot
holiday_counts.plot(kind='bar')
plt.title('Number of Holidays per Weekday')
plt.xlabel('Weekday (0=Sunday, 6=Saturday)')
plt.ylabel('Number of Holiday Hours')
plt.show()

# %%
# Create a crosstab of holidays by weekday
crosstab = pd.crosstab(finaldata_1['weekday'], finaldata_1['holiday'])

# Plot
crosstab.plot(kind='bar', stacked=True)
plt.title('Holiday vs Non-Holiday Hours per Weekday')
plt.xlabel('Weekday (0=Sunday, 6=Saturday)')
plt.ylabel('Number of Hours')
plt.legend(['Non-Holiday', 'Holiday'])
plt.show()

# %% [markdown]
# # Going to work with dataset 2
# # read data from csv file into a dataframe

# %%
data_2 = pd.read_csv("dataset_2.csv")
data_2
# Out:
#      Unnamed: 0  instant   atemp   hum  windspeed  casual  registered  cnt
# 0             0        1  0.2879  0.81     0.0000       3          13   16
# 1             1        2  0.2727  0.80     0.0000       8          32   40
# 2             2        3  0.2727  0.80     0.0000       5          27   32
# 3             3        4  0.2879  0.75     0.0000       3          10   13
# 4             4        5  0.2879  0.75     0.0000       0           1    1
# ..          ...      ...     ...   ...        ...     ...         ...  ...
# 605         605      606  0.2121  0.93     0.1045       0          30   30
# 606         606      607  0.2121  0.93     0.1045       1          28   29
# 607         607      608  0.2121  0.93     0.1045       0          31   31
# 608         608      609  0.2727  0.80     0.0000       2          36   38
# 609         609      610  0.2576  0.86     0.0000       1          40   41
#
# [610 rows x 8 columns]

# %%
#understanding the data for data cleaning by having data summary
# using shape,display info and describe for the summary

data_2.shape
# Out:
# (610, 8)

# %%
print("Displaying the info of dataset")
print(data_2.info())
# Out:
# Displaying the info of dataset
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 610 entries, 0 to 609
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  610 non-null    int64
#  1   instant     610 non-null    int64
#  2   atemp       599 non-null    float64
#  3   hum         610 non-null    float64
#  4   windspeed   610 non-null    float64
#  5   casual      610 non-null    int64
#  6   registered  610 non-null    int64
#  7   cnt         610 non-null    int64
# dtypes: float64(3), int64(5)
# memory usage: 38.3 KB
# None

# %%
data_2.describe()
# Out:
#        Unnamed: 0     instant       atemp         hum   windspeed      casual  \
# count  610.000000  610.000000  599.000000  610.000000  610.000000  610.000000
# mean   304.500000  305.500000    0.199935    0.562475    0.204851    4.501639
# std    176.236111  176.236111    0.078836    0.175440    0.121806    6.319945
# min      0.000000    1.000000    0.000000    0.210000    0.000000    0.000000
# 25%    152.250000  153.250000    0.151500    0.432500    0.104500    0.000000
# 50%    304.500000  305.500000    0.197000    0.520000    0.194000    2.000000
# 75%    456.750000  457.750000    0.242400    0.690000    0.283600    6.000000
# max    609.000000  610.000000    0.454500    1.000000    0.582100   47.000000
#
#        registered         cnt
# count  610.000000  610.000000
# mean    51.068852   55.570492
# std     47.021204   49.316802
# min      0.000000    1.000000
# 25%     14.000000   16.000000
# 50%     43.000000   47.000000
# 75%     70.000000   79.750000
# ...

# %% [markdown]
# # here i am checking,whether there is any duplicate rows or columns in the dataset.
#
# # As there are no such duplicates,we will not perform the code to remove duplicates.

# %%
duplicate_rows = data_1.duplicated()
print("Number of duplicate rows:", duplicate_rows.sum())

duplicate_columns = data_1.duplicated()
print("Number of duplicate columns:", duplicate_columns.sum())
# Out:
# Number of duplicate rows: 0
# Number of duplicate columns: 0

# %%
data_2.isnull().sum()
# Out:
# Unnamed: 0     0
# instant        0
# atemp         11
# hum            0
# windspeed      0
# casual         0
# registered     0
# cnt            0
# dtype: int64

# %%
# dropping the null values

data_2.dropna(inplace =True)
data_2
# Out:
#      Unnamed: 0  instant   atemp   hum  windspeed  casual  registered  cnt
# 0             0        1  0.2879  0.81     0.0000       3          13   16
# 1             1        2  0.2727  0.80     0.0000       8          32   40
# 2             2        3  0.2727  0.80     0.0000       5          27   32
# 3             3        4  0.2879  0.75     0.0000       3          10   13
# 4             4        5  0.2879  0.75     0.0000       0           1    1
# ..          ...      ...     ...   ...        ...     ...         ...  ...
# 605         605      606  0.2121  0.93     0.1045       0          30   30
# 606         606      607  0.2121  0.93     0.1045       1          28   29
# 607         607      608  0.2121  0.93     0.1045       0          31   31
# 608         608      609  0.2727  0.80     0.0000       2          36   38
# 609         609      610  0.2576  0.86     0.0000       1          40   41
#
# [599 rows x 8 columns]

# %%
#checking unique values for each column
# Count of unique values per column

unique_counts = data_2.nunique()

print(unique_counts)
# Out:
# Unnamed: 0    599
# instant       599
# atemp          29
# hum            61
# windspeed      20
# casual         32
# registered    150
# cnt           165
# dtype: int64

# %%
#Dropping the 'Unnamed: 0' column, because it is of no use and has same content as instant column.

finaldata_2 = data_2.drop(columns=['Unnamed: 0'])
print(finaldata_2)
# Out:
#      instant   atemp   hum  windspeed  casual  registered  cnt
# 0          1  0.2879  0.81     0.0000       3          13   16
# 1          2  0.2727  0.80     0.0000       8          32   40
# 2          3  0.2727  0.80     0.0000       5          27   32
# 3          4  0.2879  0.75     0.0000       3          10   13
# 4          5  0.2879  0.75     0.0000       0           1    1
# ..       ...     ...   ...        ...     ...         ...  ...
# 605      606  0.2121  0.93     0.1045       0          30   30
# 606      607  0.2121  0.93     0.1045       1          28   29
# 607      608  0.2121  0.93     0.1045       0          31   31
# 608      609  0.2727  0.80     0.0000       2          36   38
# 609      610  0.2576  0.86     0.0000       1          40   41
#
# [599 rows x 7 columns]

# %% [markdown]
# # making some EDAs for better understanding for dataset.

# %%
# Line graph of total count over time
#this graph shows Trends over time (Line graph): Reveals growth, seasonality, or sudden changes in bike usage.


plt.figure(figsize=(10,5))
plt.plot(finaldata_2['instant'], finaldata_2['cnt'], marker='o', linestyle='-')
plt.title('Total Count Over Time')
plt.xlabel('Instant')
plt.ylabel('Total Count (cnt)')
plt.grid(True)
plt.show()

# %%
# Sum registered and casual users
#This chart shows User segmentation (Bar graph): Highlights the proportion of regular vs. casual riders, useful for business decisions.


totals = [finaldata_2['registered'].sum(), finaldata_2['casual'].sum()]
labels = ['Registered', 'Casual']

plt.bar(labels, totals, color=['orange', 'green'])
plt.title('Total Registered vs. Casual Users')
plt.ylabel('Total Users')
plt.show()

# %%
#This line (or scatter) graph shows how the total count (cnt) changes with humidity (hum).
#it will help in Behavior patterns: Identifies optimal conditions for bike use and potential barriers (like extreme weather).


plt.plot(finaldata_2['hum'], finaldata_2['cnt'], 'bo', alpha=0.5)
plt.title('Humidity vs. Total Count')
plt.xlabel('Humidity')
plt.ylabel('Total Count (cnt)')
plt.show()

# %% [markdown]
# # we will merge our data_1 and data_2 and make new dataset_A

# %%
dataset_A= pd.merge(finaldata_1,finaldata_2,on="instant",how="inner")
dataset_A
# Out:
#      instant     dteday  season  hr  holiday  weekday  weathersit  temp  \
# 0          1 2011-01-01       1   0     True        6           1  0.24
# 1          2 2011-01-01       1   1     True        6           1  0.22
# 2          3 2011-01-01       1   2     True        6           1  0.22
# 3          4 2011-01-01       1   3     True        6           1  0.24
# 4          5 2011-01-01       1   4     True        6           1  0.24
# ..       ...        ...     ...  ..      ...      ...         ...   ...
# 594      606 2011-01-28       1  11     True        5           3  0.18
# 595      607 2011-01-28       1  12     True        5           3  0.18
# 596      608 2011-01-28       1  13     True        5           3  0.18
# 597      609 2011-01-28       1  14     True        5           3  0.22
# 598      610 2011-01-28       1  15     True        5           2  0.20
#
#       atemp   hum  windspeed  casual  registered  cnt
# ...

# %%
# Suppose your new dataset is stored in a variable called `new_dataset`
dataset_A.to_csv('dataset_A.csv', index=False)
